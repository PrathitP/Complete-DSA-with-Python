# %% [markdown]
# # Basics of Python

# %%
print("Hello World")
# Out:
# Hello World

# %%
# - Single Line Comment
'''
This is 
a Multi
Line Comment
'''
print("This was all about comments")
# Out:
# This was all about comments

# %% [markdown]
# - Indentation : These are must in python

# %%
# Line Continuation

total = 1+2+3+4+5+ \
6+7+8
print(total)
# Out:
# 36

# %%
# Multiple Statements on a Single Line 
x=10 ; y= 5 ; z = x+y;
print(z)
# Out:
# 15

# %%
# Understanding Semantics in Python 
# Variable Assignment

age = 23 # Age is a integer kernel will understand in runtime
name = "Prathit"

# %%
# Type Inference
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
# Type Inference
a = 10 
print(type(a))
a = "Prathit"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Name Error 
a=b
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 ## Name Error
# ----> 2 a=b
#       3 print(b)
#
# NameError: name 'b' is not defined

# %%
## Code Example of Indentation

if True :
    print("This is inside a if block ")
    if False :
        print('This comes when it is False')
    print("Will this be printed ?")
print("Closing of the Program")
# Out:
# This is inside a if block
# Will this be printed ?
# Closing of the Program
